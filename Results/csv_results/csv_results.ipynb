# %%
import numpy as np
import pandas as pd

# %%
csv_results1 = pd.read_csv('Comparison_Data_1.csv', encoding='unicode_escape')
csv_results1.drop(['Unnamed: 7', 'Unnamed: 8'], axis=1, inplace=True)

csv_results1_null = csv_results1[csv_results1['Rezultati'] == 0]
print(csv_results1_null.shape)
print("csv_results1 accuracy: ", csv_results1.shape[0] - csv_results1_null.shape[0], " / ", csv_results1.shape[0], " = ", (csv_results1.shape[0] - csv_results1_null.shape[0]) / csv_results1.shape[0] * 100, "%" )

csv_results1_null.head(40)
# Out:
# (39, 7)
# csv_results1 accuracy:  1973  /  2012  =  98.06163021868787 %
#      RegulationId  RegistarId  \
# 8              18          62
# 39            209         280
# 56            277         360
# 136           574         782
# 214           880        1151
# 220           892        1165
# 221           893        1166
# 253          1084        1389
# 358          1640        2025
# 359          1649        2034
#
#                                                 Naslov  \
# 8     Odluka o osnutku ?upanijskih regionalnih komora
# 39   Zakon o pribavljanju i kori­tenju inozemnih s...
# 56   Kolektivni ugovor za zaposlene u Narodnim novi...
# 136  Podaci o gra?evinskoj vrijednosti etalonskog ...
# 214  Naredba o zabrani uvoza u Republiku Hrvatsku i...
# 220  Naredba o obveznom pregledu kopitara na trihinelu
# 221  Naredba o obveznom pretra?ivanju konja na zar...
# 253      Pravilnik o osposobljavanju kadrova u lovstvu
# 358  Pravilnik o tehnikim zahtjevima za motorna i...
# 359  Pravilnik o postupku homologacije glavnih svje...
#
#                                                Vazenje Dario_StupanjeNaSnagu  \
# 8             Odluka stupa na snagu  7. 1. 1994.<br />                   NaN
# 39                   Zakon stupa na snagu  6. 5. 1978.                   NaN
# 56   Ugovor stupa na snagu i primjenjuje se 1. 1. 2...                   NaN
# 136              Ovi podaci koriste se od 1. 1. 1995.                    NaN
# 214                 Naredba stupa na snagu  13.4.2006.                   NaN
# 220                 Naredba stupa na snagu  8.12.1999.                   NaN
# 221  Naredba stupa na snagu  5.12.1994. <br/>\r\nPr...                   NaN
# 253            Praivlnik stupa na snagu  22. 7. 2006.                    NaN
# 358       Pravilnik ?e se primjenjivati s 1. 7. 2013.                   NaN
# 359  Pravilnik ?e se primjenjivati 1. 7. 2013.<br/...                   NaN
#
#     Dario_DatumPrimjene  Rezultati
# 8                   NaN          0
# 39                  NaN          0
# 56                  NaN          0
# 136                 NaN          0
# 214                 NaN          0
# 220                 NaN          0
# 221                 NaN          0
# 253                 NaN          0
# 358                 NaN          0
# 359                 NaN          0
